# %%
from dotenv import load_dotenv
from phmlondon.snow_utils import SnowflakeConnection
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import streamlit as st
import pandas as pd
import altair as alt

pd.set_option('display.max_rows', 200)
pd.set_option('display.max_columns', 100)

# %%
load_dotenv()

snowsesh = SnowflakeConnection()
snowsesh.use_database("INTELLIGENCE_DEV")
snowsesh.use_schema("AI_CENTRE_FEATURE_STORE")
# Out:
# Initiating login request with your identity provider. A browser window should have opened for you to complete the login. If you can't see it, check existing browser windows, or your OS settings. Press CTRL+C to abort and try again...
# Going to open: https://login.microsoftonline.com/8076439c-5b1f-4e15-91ea-a0bff0b3bf16/saml2?SAMLRequest=nZJBc9owEIX%2Fikc925YNplgDZEjcpMzQQrGTTrjJ9ho02JIjyRj66ysbmEkPyaE3jfR2v6d9O7k7VaV1BKmY4FPkORhZwDORM76boufk0R4jS2nKc1oKDlN0BoXuZhNFq7Im80bv%2BQbeGlDaMo24It3DFDWSE0EVU4TTChTRGYnnP5bEdzChSoHUBoeuJblihrXXuiau27at0w4cIXeujzF2cegaVSf5gt4h6s8ZtRRaZKK8lZzMnz5AeC4edgijMIT1tfCe8csIPqOkF5Ei35Nkba9XcYKs%2Be13D4KrpgIZgzyyDJ43y4sBZRzE34KRNx45zcFWwszQoX8aCY7ioi1KeoBMVHWjTWvHnNwCcrcUO2YGtoimqD6w%2FIUunuORjLO35eYp2m5f4fcxDO9fV6tzPqdPvxIql6d9lLJIZch6ucXrd%2FEulGpgwbtQtbnCfmBj38Zh4vtkMCTB2MGBt0VWZEJlnOq%2B8ua89%2BFULJNCiUILXjIOvcsx%2FjoaDsLMDlKvsIfgBXboAbUpTosCp4O08EZuF52PLutDeiNy9l9DmbjvW1zX8adJaBGtRcmys%2FUoZEX1xwF6jtffsNwueimBirJynucSlDJBlqVoHyRQbbZeywaQO7tQ%2F9372V8%3D&RelayState=ver%3A1-hint%3A8834764582918-ETMsDgAAAZTs2gKDABRBRVMvQ0JDL1BLQ1M1UGFkZGluZwEAABAAEO64ClT08E%2BAoIJCDe1LMGMAAACQ3L4JPD821JtiIvM2yUg0JyjYhZcmbTnyb7T25v42bP5fg4f6Cag2l1qetDkXEnvGcsgI3rnNgf7LOuREw5UtZz5UMq7Bn44bxfUdFWvshQicXsnTqK1Mrd40XIE9n8h4Mx6XbZBbrPezc3EO6Ky56q7KrKx6rsCaNkZSftD%2B2eaxH9lcmYa%2BIVVF%2FGDYnjLMABTXA%2BNtpK0HGNF3pDLxOUA3xIfUKA%3D%3D to authenticate...
# Snowflake session created successfully.
# Using database: INTELLIGENCE_DEV
# Using schema: AI_CENTRE_FEATURE_STORE

# %% [markdown]
# # PPMI 2D / 3D

# %%
def get_phenotype_data(snowsesh, lower_age, upper_age):
    """
    Get phenotype data for patients in age range from Snowflake.
    """
    query = f"""
    WITH age_calc AS (
        SELECT *,
               DATEDIFF(year, DATE_OF_BIRTH, CURRENT_DATE()) as age
        FROM INTELLIGENCE_DEV.AI_CENTRE_FEATURE_STORE.PERSON_5YEAR_PHENOTYPE
    )
    SELECT
        PERSON_ID,
        ASTHMA, COPD, DIABETES_TYPE2, DIABETES_TYPE1,
        HYPERTENSION, CORONARY_HEART_DISEASE, MYOCARDIAL_INFARCTION,
        TIA, STROKE, CKD_STAGE1, CKD_STAGE3, DEPRESSION,
        SEVERE_MENTAL_ILLNESS, CANCER, DEMENTIA, ATRIAL_FIBRILLATION,
        PALLIATIVE_CARE, HEART_FAILURE
    FROM age_calc
    WHERE age >= {lower_age} AND age <= {upper_age}
    """

    return snowsesh.execute_query_to_df(query)

# %%
lower_age = 18
upper_age = 79

df = get_phenotype_data(snowsesh, lower_age, upper_age)
phenotype_cols = [col for col in df.columns if col != 'PERSON_ID']
n_phenotypes = len(phenotype_cols)
# Out:
# Error executing query: (1304): 01ba494a-0000-79a3-0000-08090e4de3aa: 000904 (42000): SQL compilation error: error line 8 at position 22
# invalid identifier 'DIABETES'
# ---------------------------------------------------------------------------
# SnowparkSQLException                      Traceback (most recent call last)
# Cell In[4], line 4
#       1 lower_age = 18
#       2 upper_age = 79
# ----> 4 df = get_phenotype_data(snowsesh, lower_age, upper_age)
#       5 phenotype_cols = [col for col in df.columns if col != 'PERSON_ID']
#       6 n_phenotypes = len(phenotype_cols)
#
# Cell In[3], line 22, in get_phenotype_data(snowsesh, lower_age, upper_age)
#       2 """
#       3 Get phenotype data for patients in age range from Snowflake.
#       4 """
#       5 query = f"""
#       6 WITH age_calc AS (
#       7     SELECT *,
#    (...)
#      19 WHERE age >= {lower_age} AND age <= {upper_age}
#      20 """
# ---> 22 return snowsesh.execute_query_to_df(query)
#
# File ~/repos/d3london/onelondon_snowflake_datascience/src/phmlondon/snow_utils.py:237, in SnowflakeConnection.execute_query_to_df(self, query)
#     235 except Exception as e:
#     236     print(f"Error executing query: {e}")
# --> 237     raise e
#
# File ~/repos/d3london/onelondon_snowflake_datascience/src/phmlondon/snow_utils.py:233, in SnowflakeConnection.execute_query_to_df(self, query)
#     228 """
#     229 Executes a SQL query and returns results as a pandas DataFrame
#     230     query: predefined query
#     231 """
#     232 try:
# --> 233     result = self.session.sql(query).collect()
#     234     return pd.DataFrame(result)
#     235 except Exception as e:
#
# File ~/.pyenv/versions/snowpark/lib/python3.11/site-packages/snowflake/snowpark/_internal/telemetry.py:156, in df_collect_api_telemetry.<locals>.wrap(*args, **kwargs)
#     153 @functools.wraps(func)
#     154 def wrap(*args, **kwargs):
#     155     with args[0]._session.query_history() as query_history:
# --> 156         result = func(*args, **kwargs)
#     157     plan = args[0]._select_statement or args[0]._plan
#     158     api_calls = [
#     159         *plan.api_calls,
#     160         {TelemetryField.NAME.value: f"DataFrame.{func.__name__}"},
#     161     ]
#
# File ~/.pyenv/versions/snowpark/lib/python3.11/site-packages/snowflake/snowpark/dataframe.py:603, in DataFrame.collect(self, statement_params, block, log_on_exception, case_sensitive)
#     588 """Executes the query representing this DataFrame and returns the result as a
#     589 list of :class:`Row` objects.
#     590
#    (...)
#     600     :meth:`collect_nowait()`
#     601 """
#     602 with open_telemetry_context_manager(self.collect, self):
# --> 603     return self._internal_collect_with_tag_no_telemetry(
#     604         statement_params=statement_params,
#     605         block=block,
#     606         log_on_exception=log_on_exception,
#     607         case_sensitive=case_sensitive,
#     608     )
#
# File ~/.pyenv/versions/snowpark/lib/python3.11/site-packages/snowflake/snowpark/dataframe.py:651, in DataFrame._internal_collect_with_tag_no_telemetry(self, statement_params, block, data_type, log_on_exception, case_sensitive)
#     639 def _internal_collect_with_tag_no_telemetry(
#     640     self,
#     641     *,
#    (...)
#     649     # we should always call this method instead of collect(), to make sure the
#     650     # query tag is set properly.
# --> 651     return self._session._conn.execute(
#     652         self._plan,
#     653         block=block,
#     654         data_type=data_type,
#     655         _statement_params=create_or_update_statement_params_with_query_tag(
#     656             statement_params or self._statement_params,
#     657             self._session.query_tag,
#     658             SKIP_LEVELS_THREE,
#     659         ),
#     660         log_on_exception=log_on_exception,
#     661         case_sensitive=case_sensitive,
#     662     )
#
# File ~/.pyenv/versions/snowpark/lib/python3.11/site-packages/snowflake/snowpark/_internal/server_connection.py:526, in ServerConnection.execute(self, plan, to_pandas, to_iter, block, data_type, log_on_exception, case_sensitive, **kwargs)
#     516 if (
#     517     is_in_stored_procedure()
#     518     and not block
#    (...)
#     521     )
#     522 ):  # pragma: no cover
#     523     raise NotImplementedError(
#     524         "Async query is not supported in stored procedure yet"
#     525     )
# --> 526 result_set, result_meta = self.get_result_set(
#     527     plan,
#     528     to_pandas,
#     529     to_iter,
#     530     **kwargs,
#     531     block=block,
#     532     data_type=data_type,
#     533     log_on_exception=log_on_exception,
#     534     case_sensitive=case_sensitive,
#     535 )
#     536 if not block:
#     537     return result_set
#
# File ~/.pyenv/versions/snowpark/lib/python3.11/site-packages/snowflake/snowpark/_internal/analyzer/snowflake_plan.py:202, in SnowflakePlan.Decorator.wrap_exception.<locals>.wrap(*args, **kwargs)
#     198     else:
#     199         ne = SnowparkClientExceptionMessages.SQL_EXCEPTION_FROM_PROGRAMMING_ERROR(
#     200             e
#     201         )
# --> 202         raise ne.with_traceback(tb) from None
#     203 else:
#     204     ne = SnowparkClientExceptionMessages.SQL_EXCEPTION_FROM_PROGRAMMING_ERROR(
#     205         e
#     206     )
#
# File ~/.pyenv/versions/snowpark/lib/python3.11/site-packages/snowflake/snowpark/_internal/analyzer/snowflake_plan.py:138, in SnowflakePlan.Decorator.wrap_exception.<locals>.wrap(*args, **kwargs)
#     136 def wrap(*args, **kwargs):
#     137     try:
# --> 138         return func(*args, **kwargs)
#     139     except snowflake.connector.errors.ProgrammingError as e:
#     140         query = getattr(e, "query", None)
#
# File ~/.pyenv/versions/snowpark/lib/python3.11/site-packages/snowflake/snowpark/_internal/server_connection.py:633, in ServerConnection.get_result_set(self, plan, to_pandas, to_iter, block, data_type, log_on_exception, case_sensitive, ignore_results, **kwargs)
#     631 for holder, id_ in placeholders.items():
#     632     final_query = final_query.replace(holder, id_)
# --> 633 result = self.run_query(
#     634     final_query,
#     635     to_pandas,
#     636     to_iter and (i == len(main_queries) - 1),
#     637     is_ddl_on_temp_object=query.is_ddl_on_temp_object,
#     638     block=not is_last,
#     639     data_type=data_type,
#     640     async_job_plan=plan,
#     641     log_on_exception=log_on_exception,
#     642     case_sensitive=case_sensitive,
#     643     params=query.params,
#     644     ignore_results=ignore_results,
#     645     **kwargs,
#     646 )
#     647 placeholders[query.query_id_place_holder] = (
#     648     result["sfqid"] if not is_last else result.query_id
#     649 )
#     650 result_meta = get_new_description(self._cursor)
#
# File ~/.pyenv/versions/snowpark/lib/python3.11/site-packages/snowflake/snowpark/_internal/server_connection.py:125, in ServerConnection._Decorator.wrap_exception.<locals>.wrap(*args, **kwargs)
#     121     raise SnowparkClientExceptionMessages.SERVER_SESSION_EXPIRED(
#     122         ex.cause
#     123     )
#     124 except Exception as ex:
# --> 125     raise ex
#
# File ~/.pyenv/versions/snowpark/lib/python3.11/site-packages/snowflake/snowpark/_internal/server_connection.py:119, in ServerConnection._Decorator.wrap_exception.<locals>.wrap(*args, **kwargs)
#     117     raise SnowparkClientExceptionMessages.SERVER_SESSION_HAS_BEEN_CLOSED()
#     118 try:
# --> 119     return func(*args, **kwargs)
#     120 except ReauthenticationRequest as ex:
#     121     raise SnowparkClientExceptionMessages.SERVER_SESSION_EXPIRED(
#     122         ex.cause
#     123     )
#
# File ~/.pyenv/versions/snowpark/lib/python3.11/site-packages/snowflake/snowpark/_internal/server_connection.py:433, in ServerConnection.run_query(self, query, to_pandas, to_iter, is_ddl_on_temp_object, block, data_type, async_job_plan, log_on_exception, case_sensitive, params, num_statements, ignore_results, **kwargs)
#     431         query_id_log = f" [queryID: {ex.sfqid}]" if hasattr(ex, "sfqid") else ""
#     432         logger.error(f"Failed to execute query{query_id_log} {query}\n{ex}")
# --> 433     raise ex
#     435 # fetch_pandas_all/batches() only works for SELECT statements
#     436 # We call fetchall() if fetch_pandas_all/batches() fails,
#     437 # because when the query plan has multiple queries, it will
#     438 # have non-select statements, and it shouldn't fail if the user
#     439 # calls to_pandas() to execute the query.
#     440 if block:
#
# File ~/.pyenv/versions/snowpark/lib/python3.11/site-packages/snowflake/snowpark/_internal/server_connection.py:418, in ServerConnection.run_query(self, query, to_pandas, to_iter, is_ddl_on_temp_object, block, data_type, async_job_plan, log_on_exception, case_sensitive, params, num_statements, ignore_results, **kwargs)
#     416     kwargs["_statement_params"]["SNOWPARK_SKIP_TXN_COMMIT_IN_DDL"] = True
#     417 if block:
# --> 418     results_cursor = self.execute_and_notify_query_listener(
#     419         query, params=params, **kwargs
#     420     )
#     421     logger.debug(f"Execute query [queryID: {results_cursor.sfqid}] {query}")
#     422 else:
#
# File ~/.pyenv/versions/snowpark/lib/python3.11/site-packages/snowflake/snowpark/_internal/server_connection.py:369, in ServerConnection.execute_and_notify_query_listener(self, query, **kwargs)
#     366 def execute_and_notify_query_listener(
#     367     self, query: str, **kwargs: Any
#     368 ) -> SnowflakeCursor:
# --> 369     results_cursor = self._cursor.execute(query, **kwargs)
#     370     self.notify_query_listeners(
#     371         QueryRecord(results_cursor.sfqid, results_cursor.query)
#     372     )
#     373     return results_cursor
#
# File ~/.pyenv/versions/snowpark/lib/python3.11/site-packages/snowflake/connector/cursor.py:1087, in SnowflakeCursor.execute(self, command, params, _bind_stage, timeout, _exec_async, _no_retry, _do_reset, _put_callback, _put_azure_callback, _put_callback_output_stream, _get_callback, _get_azure_callback, _get_callback_output_stream, _show_progress_bar, _statement_params, _is_internal, _describe_only, _no_results, _is_put_get, _raise_put_get_error, _force_put_overwrite, _skip_upload_on_content_match, file_stream, num_statements, _dataframe_ast)
#    1083     is_integrity_error = (
#    1084         code == "100072"
#    1085     )  # NULL result in a non-nullable column
#    1086     error_class = IntegrityError if is_integrity_error else ProgrammingError
# -> 1087     Error.errorhandler_wrapper(self.connection, self, error_class, errvalue)
#    1088 return self
#
# File ~/.pyenv/versions/snowpark/lib/python3.11/site-packages/snowflake/connector/errors.py:284, in Error.errorhandler_wrapper(connection, cursor, error_class, error_value)
#     261 @staticmethod
#     262 def errorhandler_wrapper(
#     263     connection: SnowflakeConnection | None,
#    (...)
#     266     error_value: dict[str, Any],
#     267 ) -> None:
#     268     """Error handler wrapper that calls the errorhandler method.
#     269
#     270     Args:
#    (...)
#     281         exception to the first handler in that order.
#     282     """
# --> 284     handed_over = Error.hand_to_other_handler(
#     285         connection,
#     286         cursor,
#     287         error_class,
#     288         error_value,
#     289     )
#     290     if not handed_over:
#     291         raise Error.errorhandler_make_exception(
#     292             error_class,
#     293             error_value,
#     294         )
#
# File ~/.pyenv/versions/snowpark/lib/python3.11/site-packages/snowflake/connector/errors.py:339, in Error.hand_to_other_handler(connection, cursor, error_class, error_value)
#     337 if cursor is not None:
#     338     cursor.messages.append((error_class, error_value))
# --> 339     cursor.errorhandler(connection, cursor, error_class, error_value)
#     340     return True
#     341 elif connection is not None:
#
# File ~/.pyenv/versions/snowpark/lib/python3.11/site-packages/snowflake/connector/errors.py:215, in Error.default_errorhandler(connection, cursor, error_class, error_value)
#     213 errno = error_value.get("errno")
#     214 done_format_msg = error_value.get("done_format_msg")
# --> 215 raise error_class(
#     216     msg=error_value.get("msg"),
#     217     errno=None if errno is None else int(errno),
#     218     sqlstate=error_value.get("sqlstate"),
#     219     sfqid=error_value.get("sfqid"),
#     220     query=error_value.get("query"),
#     221     done_format_msg=(
#     222         None if done_format_msg is None else bool(done_format_msg)
#     223     ),
#     224     connection=connection,
#     225     cursor=cursor,
#     226 )
#
# SnowparkSQLException: (1304): 01ba494a-0000-79a3-0000-08090e4de3aa: 000904 (42000): SQL compilation error: error line 8 at position 22
# invalid identifier 'DIABETES'

# %%
# 2D PPMI

# empty co-occurrence matrix
cooccurrence_matrix = np.zeros((n_phenotypes, n_phenotypes))

# calculate co-occurrence
for i, pheno1 in enumerate(phenotype_cols):
    for j, pheno2 in enumerate(phenotype_cols):

        cooccurrence_matrix[i, j] = ((df[pheno1] == 1) & (df[pheno2] == 1)).sum()

# to dataframe
cooccurrence_df = pd.DataFrame(
    cooccurrence_matrix,
    index=phenotype_cols,
    columns=phenotype_cols
)

# ppmi - individual probabilities
total_patients = len(df)
individual_probs = {col: (df[col] == 1).sum() / total_patients for col in phenotype_cols}

# ppmi - matrix
ppmi_matrix = np.zeros((n_phenotypes, n_phenotypes))
for i, pheno1 in enumerate(phenotype_cols):
    for j, pheno2 in enumerate(phenotype_cols):
        # joint probability
        p_xy = cooccurrence_matrix[i, j] / total_patients
        # individual probabilities
        p_x = individual_probs[pheno1]
        p_y = individual_probs[pheno2]

        # calculate ppmi (epsilon smoothing to avoid log(0))
        epsilon = 1e-10
        pmi = np.log((p_xy + epsilon) / ((p_x * p_y) + epsilon))
        ppmi_matrix[i, j] = max(0, pmi)

# PPMI df
ppmi_df = pd.DataFrame(
    ppmi_matrix,
    index=phenotype_cols,
    columns=phenotype_cols
)

ppmi_df.to_csv('ppmi_2d.csv')

# print top pairs
print("Top phenotype associations (by PPMI):")
upper_tri = np.triu(ppmi_matrix, k=1)
indices = np.unravel_index(np.argsort(upper_tri.ravel())[-20:], upper_tri.shape)
for idx in zip(*indices):
    print(f"{phenotype_cols[idx[0]]} - {phenotype_cols[idx[1]]}: {ppmi_matrix[idx]:.2f}")

# %%
# empty 3d co-occurrence matrix
cooccurrence_3d = np.zeros((n_phenotypes, n_phenotypes, n_phenotypes))

# calculate co-occurrences
for i, pheno1 in enumerate(phenotype_cols):
    for j, pheno2 in enumerate(phenotype_cols):
        for k, pheno3 in enumerate(phenotype_cols):
            # Count patients with all three conditions
            cooccurrence_3d[i, j, k] = (
                (df[pheno1] == 1) &
                (df[pheno2] == 1) &
                (df[pheno3] == 1)
            ).sum()

# ppmi - individual probabilities
total_patients = len(df)
individual_probs = {col: (df[col] == 1).sum() / total_patients for col in phenotype_cols}

# ppmi - pair probabilities (will need for expected probabilities)
pair_probs = {}
for i, pheno1 in enumerate(phenotype_cols):
    for j, pheno2 in enumerate(phenotype_cols):
        pair_key = (pheno1, pheno2)
        pair_probs[pair_key] = ((df[pheno1] == 1) & (df[pheno2] == 1)).sum() / total_patients

# 3D array for ppmi
ppmi_3d = np.zeros((n_phenotypes, n_phenotypes, n_phenotypes))
epsilon = 1e-10

for i, pheno1 in enumerate(phenotype_cols):
    for j, pheno2 in enumerate(phenotype_cols):
        for k, pheno3 in enumerate(phenotype_cols):
            # joint probability
            p_xyz = cooccurrence_3d[i, j, k] / total_patients

            # individual probabilities
            p_x = individual_probs[pheno1]
            p_y = individual_probs[pheno2]
            p_z = individual_probs[pheno3]

            # expected probability
            expected_prob = p_x * p_y * p_z

            # Calculate PPMI
            pmi = np.log((p_xyz + epsilon) / (expected_prob + epsilon))
            ppmi_3d[i, j, k] = max(0, pmi)


# top unique combinations
top_relationships = []

for i in range(n_phenotypes):
    for j in range(i+1, n_phenotypes):
        for k in range(j+1, n_phenotypes):
            score = ppmi_3d[i, j, k]
            if score > 0:  # Only include positive associations
                top_relationships.append({
                    'conditions': (phenotype_cols[i], phenotype_cols[j], phenotype_cols[k]),
                    'ppmi': score,
                    'count': cooccurrence_3d[i, j, k]
                })
top_relationships.sort(key=lambda x: x['ppmi'], reverse=True)

# PPMI df
relationships_data = []
for i in range(n_phenotypes):
    for j in range(n_phenotypes):
        for k in range(n_phenotypes):
            relationships_data.append({
                'condition1': phenotype_cols[i],
                'condition2': phenotype_cols[j],
                'condition3': phenotype_cols[k],
                'ppmi': ppmi_3d[i, j, k],
                'count': cooccurrence_3d[i, j, k]
            })
relationships_df = pd.DataFrame(relationships_data)
relationships_df.to_csv('ppmi_3d.csv', index=False)

# top relationships
print("Top 3D phenotype associations (by PPMI):")
for rel in top_relationships[:20]:
    print(f"{rel['conditions']}: PPMI={rel['ppmi']:.2f}, Count={rel['count']:.0f}")
